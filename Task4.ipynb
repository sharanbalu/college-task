# %% [markdown]
# <a href="https://colab.research.google.com/github/sharanbalu/college-task/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
# !pip install pandas 
import pandas as pd
import numpy as np
import seaborn as sn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df1=pd.read_csv('/content/college_1.csv')
df2=pd.read_csv('/content/college_2.csv')

# %%
df1=pd.DataFrame(df1)
df2=pd.DataFrame(df2)

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %% [markdown]
# 1. merge() for combining data on common columns or indices
#
# 2. .join() for combining data on a key column or an index
# 3. concat() for combining DataFrames across rows or columns

# %%
data=pd.merge(df1,df2)
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
# Empty DataFrame
# Columns: [Name, python, mysql, Previous Geekions, CodeKata Score, Department, Rising, python_en, computational_thinking]
# Index: []

# %%
output1 = pd.merge(df1,df2, on='', how='inner')

# %%
df3 = pd.concat([df1,df2])
df3.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
df3
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
df3.describe()
# Out:
#            python       mysql  Previous Geekions  CodeKata Score       Rising  \
# count  119.000000  119.000000         119.000000      119.000000   119.000000
# mean    54.352941   23.500000        3842.352941     4051.764706   209.411765
# std     44.272526   33.276671        4406.339992     4551.951881   553.445746
# min     -1.000000   -1.000000           0.000000        0.000000     0.000000
# 25%      0.000000    0.000000         740.000000      740.000000     0.000000
# 50%     82.000000    4.000000        2410.000000     2410.000000     0.000000
# 75%    100.000000   33.000000        5340.000000     5975.000000     0.000000
# max    100.000000  100.000000       24500.000000    24500.000000  3140.000000
#
#         python_en  computational_thinking
# count   35.000000               35.000000
# mean    29.657143                2.200000
# std     30.582524                7.015948
# min     -1.000000               -1.000000
# 25%      0.000000                0.000000
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
# splitting dataframe by row index
df1 = df1.iloc[:1000,:]
df2 = df2.iloc[1000:,:]
print("Shape of new dataframes - {} , {}".format(df1.shape, df2.shape))
# Out:
# Shape of new dataframes - (119, 9) , (0, 9)

# %%
# splitting DF1 bases on coulomn
df1.iloc[:,[0,4]]
# Out:
#              Name  CodeKata Score
# 0       A.Dharani           24500
# 1     V.JEEVITHA            21740
# 2     HEMAVATHI.R           19680
# 3     Mugunthan S           10610
# 4     Sathammai.S            8980
# ..            ...             ...
# 30  praveen raj j            2380
# 31     AMARNATH D            1890
# 32           bala            1720
# 33           XY Z               0
# 34      Hariharan               0
#
# [119 rows x 2 columns]

# %%
# On Department
df1.iloc[:,[0,5]]
# Out:
#              Name                                 Department
# 0       A.Dharani           Computer Science and Engineering
# 1     V.JEEVITHA            Computer Science and Engineering
# 2     HEMAVATHI.R           Computer Science and Engineering
# 3     Mugunthan S           Computer Science and Engineering
# 4     Sathammai.S           Computer Science and Engineering
# ..            ...                                        ...
# 30  praveen raj j           Computer Science and Engineering
# 31     AMARNATH D  Electronics and Communication Engineering
# 32           bala  Electronics and Communication Engineering
# 33           XY Z           Computer Science and Engineering
# 34      Hariharan           Computer Science and Engineering
#
# [119 rows x 2 columns]

# %%
#Splitting DF2

df2.iloc[:,[0,4]]
# Out:
#              Name  CodeKata Score
# 0       A.Dharani           24500
# 1     V.JEEVITHA            21740
# 2     HEMAVATHI.R           19680
# 3     Mugunthan S           10610
# 4     Sathammai.S            8980
# ..            ...             ...
# 30  praveen raj j            2380
# 31     AMARNATH D            1890
# 32           bala            1720
# 33           XY Z               0
# 34      Hariharan               0
#
# [119 rows x 2 columns]

# %%
df2.iloc[:,[0,5]]
# Out:
#              Name                                 Department
# 0       A.Dharani           Computer Science and Engineering
# 1     V.JEEVITHA            Computer Science and Engineering
# 2     HEMAVATHI.R           Computer Science and Engineering
# 3     Mugunthan S           Computer Science and Engineering
# 4     Sathammai.S           Computer Science and Engineering
# ..            ...                                        ...
# 30  praveen raj j           Computer Science and Engineering
# 31     AMARNATH D  Electronics and Communication Engineering
# 32           bala  Electronics and Communication Engineering
# 33           XY Z           Computer Science and Engineering
# 34      Hariharan           Computer Science and Engineering
#
# [119 rows x 2 columns]

# %%
grouped = df1.groupby(df.Department)
df_new = grouped.get_group("Computer Science and Engineering")
df_new

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Reached_expecttion=df3[(df3['CodeKata Score']>15000)]
Reached_expecttion
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expecttion=df3[(df3['CodeKata Score']>10000)&(df3['CodeKata Score']<15000)]
Reached_expecttion
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvement=df3[(df3['CodeKata Score']>7000)&(df3['CodeKata Score']<10000)]
Needs_Improvement
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=df3[(df3['CodeKata Score']<7000)]
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df3['Previous Geekions'].mean()
# Out:
# 3842.3529411764707

# %%
df3['CodeKata Score'].mean()
# Out:
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
df3['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df3['python'].mean()
# Out:
# 54.35294117647059

# %%
df3['mysql'].mean()
# Out:
# 23.5

# %%
df3['computational_thinking'].mean()
# Out:
# 2.2

# %%
df3['python_en'].mean()
# Out:
# 29.65714285714286

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
# top 3 largest values in column CodeKata Score
df3.nlargest(3, ['CodeKata Score'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %%
df3['CodeKata Score'].nlargest(3)
# Out:
# 0    24500
# 1    21740
# 2    19680
# Name: CodeKata Score, dtype: int64

# %%
df3['Previous Geekions'].nlargest(3)
# Out:
# 0    24500
# 1    21740
# 2    19680
# Name: Previous Geekions, dtype: int64

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
# top 3 largest values in column Previous Geekions
df3.nlargest(3, ['Previous Geekions'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
plot = df3.plot.pie(y='', label='Department',figsize=(5, 5))

# %%
df3.plot.pie(y='CodeKata Score')

# %%
df3.groupby(['']).sum().plot(kind='pie', y='points')

# %%
df3.loc['CodeKata Score', :]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sums = df3.groupby(df3["Department"])["CodeKata Score"].max()
plt.pie(sums, labels=sums.index, autopct='%1.1f%%', shadow=True, startangle=195);
plt.show()
print(sums)
# Out:
# Department
# Computer Science and Engineering             24500
# Electronics and Communication Engineering    10040
# Electronics and Electrical Engineering       19400
# Name: CodeKata Score, dtype: int64

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df = pd.DataFrame({'lab': ['A', 'B', 'C'], 'val': [10, 30, 20]})
ax = df.plot.barh(x='lab', y='val')

# %%
sums = df3.groupby(df3["Department"])["CodeKata Score"].max()
plt.bar(sums,  color ='maroon', width = 10, height= 29);
plt.show()
#print(sums)

# %%
dpp= df3['Department']
code=df3["CodeKata Score"].max()
plt.barh(dpp, code)
plt.show()
